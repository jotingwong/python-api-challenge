# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import api_key
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
# len(cities)

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | port keats
# Processing Record 9 of Set 1 | goundam
# Processing Record 10 of Set 1 | palu
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | amalapuram
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | kjollefjord
# Processing Record 15 of Set 1 | burica
# City not found. Skipping...
# Processing Record 16 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | pacific grove
# Processing Record 21 of Set 1 | caravelas
# Processing Record 22 of Set 1 | serov
# Processing Record 23 of Set 1 | ust-ilimsk
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | port lincoln
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | kununurra
# Processing Record 30 of Set 1 | denpasar
# Processing Record 31 of Set 1 | husavik
# Processing Record 32 of Set 1 | yerbogachen
# Processing Record 33 of Set 1 | oksfjord
# Processing Record 34 of Set 1 | pechenga
# Processing Record 35 of Set 1 | ahtopol
# Processing Record 36 of Set 1 | tulu bolo
# Processing Record 37 of Set 1 | shahrud
# Processing Record 38 of Set 1 | poum
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | mayo
# Processing Record 41 of Set 1 | manta
# Processing Record 42 of Set 1 | yarada
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | rudbar
# City not found. Skipping...
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 0 of Set 2 | hasaki
# Processing Record 1 of Set 2 | banjar
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | portland
# Processing Record 5 of Set 2 | hambantota
# Processing Record 6 of Set 2 | avera
# Processing Record 7 of Set 2 | sibolga
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | orhei
# Processing Record 11 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 14 of Set 2 | capitao poco
# Processing Record 15 of Set 2 | vardo
# Processing Record 16 of Set 2 | iqaluit
# Processing Record 17 of Set 2 | rovaniemi
# Processing Record 18 of Set 2 | hilo
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | arraial do cabo
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | altay
# Processing Record 24 of Set 2 | vadinsk
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | hukuntsi
# Processing Record 27 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 29 of Set 2 | north bend
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | dubki
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | kamsack
# Processing Record 35 of Set 2 | sao filipe
# Processing Record 36 of Set 2 | zhezkazgan
# Processing Record 37 of Set 2 | guspini
# Processing Record 38 of Set 2 | ancud
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | kacergine
# City not found. Skipping...
# Processing Record 41 of Set 2 | la ronge
# Processing Record 42 of Set 2 | green river
# Processing Record 43 of Set 2 | bubaque
# Processing Record 44 of Set 2 | svetlyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | issoire
# Processing Record 46 of Set 2 | hualmay
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | ekpoma
# Processing Record 49 of Set 2 | kalmunai
# Processing Record 0 of Set 3 | cagliliog
# Processing Record 1 of Set 3 | cabra
# Processing Record 2 of Set 3 | vanimo
# Processing Record 3 of Set 3 | labuhan
# Processing Record 4 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 3 | antofagasta
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | wonogiri
# Processing Record 10 of Set 3 | okhotsk
# Processing Record 11 of Set 3 | the pas
# Processing Record 12 of Set 3 | westport
# Processing Record 13 of Set 3 | monforte de lemos
# Processing Record 14 of Set 3 | jaguaquara
# Processing Record 15 of Set 3 | shimsk
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | siniscola
# Processing Record 18 of Set 3 | kutum
# Processing Record 19 of Set 3 | udachnyy
# Processing Record 20 of Set 3 | mount gambier
# Processing Record 21 of Set 3 | marau
# Processing Record 22 of Set 3 | bilibino
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | at-bashi
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | isangel
# Processing Record 30 of Set 3 | clonakilty
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | buraydah
# Processing Record 33 of Set 3 | dogondoutchi
# Processing Record 34 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | vostok
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | tasiilaq
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | dunmore town
# Processing Record 41 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 3 | taltal
# Processing Record 43 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 3 | saint stephen
# Processing Record 45 of Set 3 | tiznit
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | baykit
# Processing Record 48 of Set 3 | nsanje
# Processing Record 49 of Set 3 | naron
# Processing Record 0 of Set 4 | ust-omchug
# Processing Record 1 of Set 4 | pangnirtung
# Processing Record 2 of Set 4 | keene
# Processing Record 3 of Set 4 | tashigang
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | norman wells
# Processing Record 6 of Set 4 | carora
# Processing Record 7 of Set 4 | vila franca do campo
# Processing Record 8 of Set 4 | paka
# Processing Record 9 of Set 4 | lyuban
# Processing Record 10 of Set 4 | oistins
# Processing Record 11 of Set 4 | verkhoyansk
# Processing Record 12 of Set 4 | abu samrah
# Processing Record 13 of Set 4 | shelburne
# Processing Record 14 of Set 4 | williams lake
# Processing Record 15 of Set 4 | nikki
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | kavaratti
# Processing Record 18 of Set 4 | rocha
# Processing Record 19 of Set 4 | kelapa sawit
# Processing Record 20 of Set 4 | ambulu
# Processing Record 21 of Set 4 | ygatimi
# Processing Record 22 of Set 4 | maumere
# Processing Record 23 of Set 4 | dikson
# Processing Record 24 of Set 4 | yellowknife
# Processing Record 25 of Set 4 | nata
# Processing Record 26 of Set 4 | victoria
# Processing Record 27 of Set 4 | vestmannaeyjar
# Processing Record 28 of Set 4 | rio claro
# Processing Record 29 of Set 4 | qaqortoq
# Processing Record 30 of Set 4 | olpad
# Processing Record 31 of Set 4 | milledgeville
# Processing Record 32 of Set 4 | hamilton
# Processing Record 33 of Set 4 | apache junction
# Processing Record 34 of Set 4 | blagodatnoye
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | mahibadhoo
# Processing Record 37 of Set 4 | nikolskoye
# Processing Record 38 of Set 4 | conceicao das alagoas
# Processing Record 39 of Set 4 | port augusta
# Processing Record 40 of Set 4 | cap malheureux
# Processing Record 41 of Set 4 | deputatskiy
# Processing Record 42 of Set 4 | vernon
# Processing Record 43 of Set 4 | san francisco
# Processing Record 44 of Set 4 | bozeman
# Processing Record 45 of Set 4 | luderitz
# Processing Record 46 of Set 4 | antsohihy
# Processing Record 47 of Set 4 | grindavik
# Processing Record 48 of Set 4 | port alfred
# Processing Record 49 of Set 4 | smirnykh
# Processing Record 0 of Set 5 | shubarkuduk
# Processing Record 1 of Set 5 | san quintin
# Processing Record 2 of Set 5 | cayenne
# Processing Record 3 of Set 5 | bolshaya murta
# City not found. Skipping...
# Processing Record 4 of Set 5 | chokurdakh
# Processing Record 5 of Set 5 | neiafu
# Processing Record 6 of Set 5 | gushikawa
# Processing Record 7 of Set 5 | ostrovnoy
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | kumo
# Processing Record 10 of Set 5 | lazaro cardenas
# Processing Record 11 of Set 5 | kamenka
# Processing Record 12 of Set 5 | leon
# Processing Record 13 of Set 5 | naze
# Processing Record 14 of Set 5 | lehututu
# Processing Record 15 of Set 5 | ezhou
# Processing Record 16 of Set 5 | kulhudhuffushi
# Processing Record 17 of Set 5 | kifri
# Processing Record 18 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 5 | aitape
# Processing Record 20 of Set 5 | tacuarembo
# Processing Record 21 of Set 5 | genhe
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | yaan
# Processing Record 24 of Set 5 | kawalu
# Processing Record 25 of Set 5 | gawler
# Processing Record 26 of Set 5 | idstein
# Processing Record 27 of Set 5 | ranong
# Processing Record 28 of Set 5 | abong mbang
# Processing Record 29 of Set 5 | saint-philippe
# Processing Record 30 of Set 5 | sola
# Processing Record 31 of Set 5 | thompson
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | hay river
# Processing Record 34 of Set 5 | maldonado
# Processing Record 35 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 5 | souillac
# Processing Record 37 of Set 5 | nabire
# Processing Record 38 of Set 5 | sungaipenuh
# Processing Record 39 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 5 | brod
# Processing Record 41 of Set 5 | kijang
# Processing Record 42 of Set 5 | rapid valley
# Processing Record 43 of Set 5 | nantucket
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | sterling
# Processing Record 46 of Set 5 | la rioja
# Processing Record 47 of Set 5 | ploemeur
# Processing Record 48 of Set 5 | fairbanks
# Processing Record 49 of Set 5 | lodja
# Processing Record 0 of Set 6 | avarua
# Processing Record 1 of Set 6 | christchurch
# Processing Record 2 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 6 | ust-kuyga
# Processing Record 4 of Set 6 | henties bay
# Processing Record 5 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 6 | ambilobe
# Processing Record 7 of Set 6 | port blair
# Processing Record 8 of Set 6 | bonthe
# Processing Record 9 of Set 6 | grand gaube
# Processing Record 10 of Set 6 | telfs
# Processing Record 11 of Set 6 | korla
# City not found. Skipping...
# Processing Record 12 of Set 6 | santa ana
# Processing Record 13 of Set 6 | porto velho
# Processing Record 14 of Set 6 | awjilah
# Processing Record 15 of Set 6 | coihaique
# Processing Record 16 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 6 | waipawa
# Processing Record 18 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 6 | we
# City not found. Skipping...
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | gazanjyk
# Processing Record 22 of Set 6 | rawson
# Processing Record 23 of Set 6 | jacmel
# Processing Record 24 of Set 6 | cururupu
# Processing Record 25 of Set 6 | palenque
# Processing Record 26 of Set 6 | simpang
# Processing Record 27 of Set 6 | evensk
# Processing Record 28 of Set 6 | tucumcari
# Processing Record 29 of Set 6 | puro
# Processing Record 30 of Set 6 | manacapuru
# Processing Record 31 of Set 6 | longyearbyen
# Processing Record 32 of Set 6 | mindif
# Processing Record 33 of Set 6 | acapulco
# Processing Record 34 of Set 6 | malim
# Processing Record 35 of Set 6 | nome
# Processing Record 36 of Set 6 | varhaug
# Processing Record 37 of Set 6 | touros
# Processing Record 38 of Set 6 | oktyabrskoye
# Processing Record 39 of Set 6 | laguna
# Processing Record 40 of Set 6 | carauari
# Processing Record 41 of Set 6 | sukumo
# Processing Record 42 of Set 6 | katsuura
# Processing Record 43 of Set 6 | mercedes
# Processing Record 44 of Set 6 | grimmen
# Processing Record 45 of Set 6 | san ramon de la nueva oran
# Processing Record 46 of Set 6 | luanda
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | wuchi
# Processing Record 49 of Set 6 | eyl
# Processing Record 0 of Set 7 | taunggyi
# Processing Record 1 of Set 7 | high rock
# Processing Record 2 of Set 7 | yar-sale
# Processing Record 3 of Set 7 | salalah
# Processing Record 4 of Set 7 | batemans bay
# Processing Record 5 of Set 7 | mbandaka
# Processing Record 6 of Set 7 | moose factory
# Processing Record 7 of Set 7 | tarbagatay
# Processing Record 8 of Set 7 | dafeng
# Processing Record 9 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 7 | gubkinskiy
# Processing Record 11 of Set 7 | auki
# Processing Record 12 of Set 7 | el alto
# Processing Record 13 of Set 7 | bandar-e lengeh
# Processing Record 14 of Set 7 | aquiraz
# Processing Record 15 of Set 7 | sumbe
# Processing Record 16 of Set 7 | limon
# Processing Record 17 of Set 7 | pisco
# Processing Record 18 of Set 7 | puerto escondido
# Processing Record 19 of Set 7 | quatre cocos
# Processing Record 20 of Set 7 | goderich
# Processing Record 21 of Set 7 | kenora
# Processing Record 22 of Set 7 | belyy yar
# Processing Record 23 of Set 7 | kaitangata
# Processing Record 24 of Set 7 | cartagena del chaira
# Processing Record 25 of Set 7 | dergachi
# Processing Record 26 of Set 7 | tshikapa
# Processing Record 27 of Set 7 | sitka
# Processing Record 28 of Set 7 | venado tuerto
# Processing Record 29 of Set 7 | college
# Processing Record 30 of Set 7 | coihueco
# Processing Record 31 of Set 7 | casablanca
# Processing Record 32 of Set 7 | tura
# Processing Record 33 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 7 | juterbog
# Processing Record 35 of Set 7 | maragogi
# Processing Record 36 of Set 7 | najran
# Processing Record 37 of Set 7 | tukrah
# City not found. Skipping...
# Processing Record 38 of Set 7 | constitucion
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 7 | capreol
# Processing Record 42 of Set 7 | cherskiy
# Processing Record 43 of Set 7 | bardiyah
# City not found. Skipping...
# Processing Record 44 of Set 7 | carahue
# Processing Record 45 of Set 7 | narsaq
# Processing Record 46 of Set 7 | san patricio
# Processing Record 47 of Set 7 | sobolevo
# Processing Record 48 of Set 7 | niksic
# Processing Record 49 of Set 7 | kuala terengganu
# Processing Record 0 of Set 8 | berlevag
# Processing Record 1 of Set 8 | andenes
# City not found. Skipping...
# Processing Record 2 of Set 8 | ler
# Processing Record 3 of Set 8 | cockburn town
# Processing Record 4 of Set 8 | alghero
# Processing Record 5 of Set 8 | praia da vitoria
# Processing Record 6 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 8 | san cristobal
# Processing Record 8 of Set 8 | lebedinyy
# Processing Record 9 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 8 | sembakung
# Processing Record 11 of Set 8 | portel
# Processing Record 12 of Set 8 | port-gentil
# Processing Record 13 of Set 8 | bambous virieux
# Processing Record 14 of Set 8 | lima
# Processing Record 15 of Set 8 | umm jarr
# City not found. Skipping...
# Processing Record 16 of Set 8 | belmonte
# Processing Record 17 of Set 8 | aksha
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | antalaha
# Processing Record 20 of Set 8 | mulanje
# Processing Record 21 of Set 8 | ocos
# Processing Record 22 of Set 8 | panjwin
# City not found. Skipping...
# Processing Record 23 of Set 8 | liverpool
# Processing Record 24 of Set 8 | along
# Processing Record 25 of Set 8 | manadhoo
# Processing Record 26 of Set 8 | longview
# Processing Record 27 of Set 8 | grand-santi
# Processing Record 28 of Set 8 | zhaotong
# Processing Record 29 of Set 8 | mutis
# Processing Record 30 of Set 8 | surt
# Processing Record 31 of Set 8 | ambon
# Processing Record 32 of Set 8 | bereda
# Processing Record 33 of Set 8 | soe
# Processing Record 34 of Set 8 | kloulklubed
# Processing Record 35 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 8 | vytegra
# Processing Record 37 of Set 8 | celestun
# Processing Record 38 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 8 | prince rupert
# Processing Record 40 of Set 8 | kilindoni
# Processing Record 41 of Set 8 | salto
# Processing Record 42 of Set 8 | samarai
# Processing Record 43 of Set 8 | winnemucca
# Processing Record 44 of Set 8 | kysyl-syr
# Processing Record 45 of Set 8 | sullana
# Processing Record 46 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 47 of Set 8 | sovetskiy
# Processing Record 48 of Set 8 | loiza
# Processing Record 49 of Set 8 | sijunjung
# Processing Record 0 of Set 9 | sidi ali
# Processing Record 1 of Set 9 | otukpo
# Processing Record 2 of Set 9 | tselinnoye
# Processing Record 3 of Set 9 | agadez
# Processing Record 4 of Set 9 | faya
# Processing Record 5 of Set 9 | sechura
# Processing Record 6 of Set 9 | arman
# Processing Record 7 of Set 9 | himora
# City not found. Skipping...
# Processing Record 8 of Set 9 | tandalti
# Processing Record 9 of Set 9 | shagonar
# Processing Record 10 of Set 9 | anlu
# Processing Record 11 of Set 9 | sarkand
# Processing Record 12 of Set 9 | thinadhoo
# Processing Record 13 of Set 9 | lagoa
# Processing Record 14 of Set 9 | qabaqcol
# Processing Record 15 of Set 9 | champerico
# Processing Record 16 of Set 9 | tsumeb
# Processing Record 17 of Set 9 | shache
# Processing Record 18 of Set 9 | mizdah
# Processing Record 19 of Set 9 | thano bula khan
# City not found. Skipping...
# Processing Record 20 of Set 9 | abonnema
# Processing Record 21 of Set 9 | tyup
# Processing Record 22 of Set 9 | raga
# City not found. Skipping...
# Processing Record 23 of Set 9 | skjervoy
# Processing Record 24 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 9 | vastervik
# City not found. Skipping...
# Processing Record 26 of Set 9 | flin flon
# Processing Record 27 of Set 9 | komsomolskiy
# Processing Record 28 of Set 9 | seoul
# Processing Record 29 of Set 9 | codrington
# Processing Record 30 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 31 of Set 9 | lompoc
# Processing Record 32 of Set 9 | kharan
# Processing Record 33 of Set 9 | sibu
# Processing Record 34 of Set 9 | ilinskiy
# Processing Record 35 of Set 9 | sharan
# Processing Record 36 of Set 9 | leningradskiy
# Processing Record 37 of Set 9 | berbera
# City not found. Skipping...
# Processing Record 38 of Set 9 | klaksvik
# Processing Record 39 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 9 | fort nelson
# Processing Record 41 of Set 9 | progreso
# Processing Record 42 of Set 9 | skagen
# Processing Record 43 of Set 9 | bambanglipuro
# Processing Record 44 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 9 | laiyang
# Processing Record 46 of Set 9 | trinidad
# Processing Record 47 of Set 9 | preobrazheniye
# Processing Record 48 of Set 9 | camacha
# Processing Record 49 of Set 9 | anadyr
# Processing Record 0 of Set 10 | nuevo progreso
# Processing Record 1 of Set 10 | tessalit
# Processing Record 2 of Set 10 | murdochville
# Processing Record 3 of Set 10 | wanning
# Processing Record 4 of Set 10 | cowra
# Processing Record 5 of Set 10 | bowral
# Processing Record 6 of Set 10 | fowa
# Processing Record 7 of Set 10 | nokha
# Processing Record 8 of Set 10 | talnakh
# Processing Record 9 of Set 10 | manicore
# Processing Record 10 of Set 10 | butembo
# Processing Record 11 of Set 10 | vila velha
# Processing Record 12 of Set 10 | nerchinskiy zavod
# Processing Record 13 of Set 10 | srandakan
# Processing Record 14 of Set 10 | saint george
# Processing Record 15 of Set 10 | ayan
# Processing Record 16 of Set 10 | diamantino
# Processing Record 17 of Set 10 | arlit
# Processing Record 18 of Set 10 | sungai siput utara
# City not found. Skipping...
# Processing Record 19 of Set 10 | mindelo
# Processing Record 20 of Set 10 | ruwi
# Processing Record 21 of Set 10 | takoradi
# Processing Record 22 of Set 10 | sioux lookout
# Processing Record 23 of Set 10 | abha
# Processing Record 24 of Set 10 | arecibo
# Processing Record 25 of Set 10 | torun
# Processing Record 26 of Set 10 | mandalgovi
# Processing Record 27 of Set 10 | hofn
# Processing Record 28 of Set 10 | soyo
# Processing Record 29 of Set 10 | itanhandu
# Processing Record 30 of Set 10 | riyadh
# Processing Record 31 of Set 10 | rio grande
# Processing Record 32 of Set 10 | daru
# Processing Record 33 of Set 10 | anloga
# Processing Record 34 of Set 10 | brawley
# Processing Record 35 of Set 10 | tateyama
# Processing Record 36 of Set 10 | amlagora
# Processing Record 37 of Set 10 | taitung
# Processing Record 38 of Set 10 | chokwe
# City not found. Skipping...
# Processing Record 39 of Set 10 | griffith
# Processing Record 40 of Set 10 | ketchikan
# Processing Record 41 of Set 10 | clyde river
# Processing Record 42 of Set 10 | boa vista
# Processing Record 43 of Set 10 | yeppoon
# Processing Record 44 of Set 10 | kismayo
# City not found. Skipping...
# Processing Record 45 of Set 10 | san miguel chicaj
# Processing Record 46 of Set 10 | ulaangom
# Processing Record 47 of Set 10 | yulara
# Processing Record 48 of Set 10 | beidao
# Processing Record 49 of Set 10 | matadi
# Processing Record 0 of Set 11 | petatlan
# Processing Record 1 of Set 11 | molteno
# Processing Record 2 of Set 11 | novaya zaimka
# Processing Record 3 of Set 11 | lengshuitan
# Processing Record 4 of Set 11 | theodoriana
# Processing Record 5 of Set 11 | atherton
# Processing Record 6 of Set 11 | general roca
# Processing Record 7 of Set 11 | blagoyevo
# Processing Record 8 of Set 11 | moerai
# Processing Record 9 of Set 11 | livingston
# Processing Record 10 of Set 11 | atar
# Processing Record 11 of Set 11 | wilkie
# Processing Record 12 of Set 11 | gat
# Processing Record 13 of Set 11 | nikita
# Processing Record 14 of Set 11 | issenye
# Processing Record 15 of Set 11 | ust-nera
# Processing Record 16 of Set 11 | wilmington
# Processing Record 17 of Set 11 | bollnas
# Processing Record 18 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 11 | raudeberg
# Processing Record 20 of Set 11 | dunedin
# Processing Record 21 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 22 of Set 11 | athabasca
# Processing Record 23 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 24 of Set 11 | matara
# Processing Record 25 of Set 11 | fianga
# City not found. Skipping...
# Processing Record 26 of Set 11 | camana
# City not found. Skipping...
# Processing Record 27 of Set 11 | kaeo
# Processing Record 28 of Set 11 | lasa
# Processing Record 29 of Set 11 | borama
# City not found. Skipping...
# Processing Record 30 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 31 of Set 11 | aguada de pasajeros
# Processing Record 32 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 33 of Set 11 | zhengjiatun
# Processing Record 34 of Set 11 | pimentel
# Processing Record 35 of Set 11 | moron
# Processing Record 36 of Set 11 | shingu
# Processing Record 37 of Set 11 | pervomayskiy
# Processing Record 38 of Set 11 | plouzane
# Processing Record 39 of Set 11 | orodara
# Processing Record 40 of Set 11 | viedma
# Processing Record 41 of Set 11 | phalombe
# Processing Record 42 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 11 | biak
# Processing Record 44 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 11 | omboue
# Processing Record 46 of Set 11 | svirstroy
# Processing Record 47 of Set 11 | ukiah
# Processing Record 48 of Set 11 | jadu
# Processing Record 49 of Set 11 | port-cartier
# Processing Record 0 of Set 12 | machachi
# Processing Record 1 of Set 12 | khasan
# Processing Record 2 of Set 12 | khani
# Processing Record 3 of Set 12 | luwuk
# Processing Record 4 of Set 12 | atambua
# Processing Record 5 of Set 12 | broome
# Processing Record 6 of Set 12 | roma
# Processing Record 7 of Set 12 | santa lucia
# Processing Record 8 of Set 12 | brae
# Processing Record 9 of Set 12 | groa
# Processing Record 10 of Set 12 | dunkirk
# Processing Record 11 of Set 12 | namatanai
# Processing Record 12 of Set 12 | tuatapere
# Processing Record 13 of Set 12 | comodoro rivadavia
# Processing Record 14 of Set 12 | caranavi
# Processing Record 15 of Set 12 | tralee
# Processing Record 16 of Set 12 | ulaanbaatar
# Processing Record 17 of Set 12 | mananjary
# Processing Record 18 of Set 12 | kibondo
# Processing Record 19 of Set 12 | rio gallegos
# Processing Record 20 of Set 12 | cervo
# Processing Record 21 of Set 12 | caraguatatuba
# Processing Record 22 of Set 12 | abu kamal
# Processing Record 23 of Set 12 | ariquemes
# Processing Record 24 of Set 12 | ruteng
# Processing Record 25 of Set 12 | placido de castro
# Processing Record 26 of Set 12 | keti bandar
# Processing Record 27 of Set 12 | egvekinot
# Processing Record 28 of Set 12 | bandarbeyla
# Processing Record 29 of Set 12 | savannakhet
# Processing Record 30 of Set 12 | sorong
# Processing Record 31 of Set 12 | nanortalik
# Processing Record 32 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 12 | te anau
# Processing Record 34 of Set 12 | kyra
# City not found. Skipping...
# Processing Record 35 of Set 12 | mount pleasant
# Processing Record 36 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 37 of Set 12 | megion
# Processing Record 38 of Set 12 | meulaboh
# Processing Record 39 of Set 12 | olinda
# Processing Record 40 of Set 12 | santa clara
# Processing Record 41 of Set 12 | myitkyina
# Processing Record 42 of Set 12 | kushmurun
# City not found. Skipping...
# Processing Record 43 of Set 12 | veraval
# Processing Record 44 of Set 12 | candido mendes
# Processing Record 45 of Set 12 | semey
# Processing Record 46 of Set 12 | wuning
# Processing Record 47 of Set 12 | tilichiki
# Processing Record 48 of Set 12 | salinopolis
# Processing Record 49 of Set 12 | tall kayf
# Processing Record 0 of Set 13 | tepecoacuilco
# City not found. Skipping...
# Processing Record 1 of Set 13 | ardahan
# Processing Record 2 of Set 13 | jauharabad
# Processing Record 3 of Set 13 | kandiaro
# Processing Record 4 of Set 13 | narasannapeta
# Processing Record 5 of Set 13 | derzhavinsk
# Processing Record 6 of Set 13 | flinders
# Processing Record 7 of Set 13 | ahipara
# Processing Record 8 of Set 13 | zhigansk
# Processing Record 9 of Set 13 | broken hill
# Processing Record 10 of Set 13 | ucluelet
# Processing Record 11 of Set 13 | carballo
# Processing Record 12 of Set 13 | severnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
